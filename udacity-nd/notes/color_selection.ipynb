# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
# Read the image and print out some stats
image = mpimg.imread('images/test.jpg')
print(f"This image is {type(image)} with dimensions {image.shape}")

# Gran the x and y size and make a copy of the image
ysize = image.shape[0]
xsize = image.shape[1]
# Out:
# This image is <class 'numpy.ndarray'> with dimensions (540, 960, 3)

# %%
# Note: always make a copy rather than simply using "="
color_select = np.copy(image)
# Define our color selection criteria
red_threshold = 199
green_threshold = 199
blue_threshold = 199

rgb_threshold = [red_threshold, green_threshold, blue_threshold]

# %%
# Identify pixels below the threshold
thresholds = (image[:,:,0] < rgb_threshold[0]) \
            | (image[:,:,1] < rgb_threshold[1]) \
            | (image[:,:,2] < rgb_threshold[2])
# print(thresholds)
color_select[thresholds] = [0,0,0]

# Display the image
f, (original, lane) = plt.subplots(1,2, figsize=(20,10))
original.set_title("original")
original.imshow(image)
lane.set_title("lane")
lane.imshow(color_select)
